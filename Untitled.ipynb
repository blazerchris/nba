# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('seasonRanks91to95.csv')

# %%
df1 = pd.read_csv('seasonRanks.csv')

# %%
df1['Year'].unique()
# Out:
# array([1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype=int64)

# %%
df['Year'].unique()
# Out:
# array([1991, 1992, 1993, 1994, 1995], dtype=int64)

# %%
df2 = pd.concat([df,df1])

# %%
df2['Year'].unique()
# Out:
# array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017], dtype=int64)

# %%
df2.to_csv('seasonRanks91to17.csv',index=False)

# %%
df2
# Out:
#      Year   Div Team  Wins
# 0    1991  East  BOS    56
# 1    1991  East  PHI    44
# 2    1991  East  NYK    39
# 3    1991  East  WSB    30
# 4    1991  East  NJN    26
# 5    1991  East  MIA    24
# 6    1991  East  CHI    61
# 7    1991  East  DET    50
# 8    1991  East  MIL    48
# 9    1991  East  ATL    43
# 10   1991  East  IND    41
# 11   1991  East  CLE    33
# 12   1991  East  CHH    26
# 13   1991  West  SAS    55
# 14   1991  West  UTA    54
# 15   1991  West  HOU    52
# 16   1991  West  ORL    31
# 17   1991  West  MIN    29
# 18   1991  West  DAL    28
# 19   1991  West  DEN    20
# 20   1991  West  POR    63
# 21   1991  West  LAL    58
# 22   1991  West  PHO    55
# 23   1991  West  GSW    44
# 24   1991  West  SEA    41
# 25   1991  West  LAC    31
# 26   1991  West  SAC    25
# 27   1992  East  BOS    51
# 28   1992  East  NYK    51
# 29   1992  East  NJN    40
# ..    ...   ...  ...   ...
# 621  2017  East  BOS    53
# 622  2017  East  CLE    51
# ...

# %%
NBA_Salary_1991 = pd.read_csv('NBA_Salary_1991.csv')

# %%
NBA_Salary_1992 = pd.read_csv('NBA_Salary_1992.csv')

# %%
NBA_Salary_1993 = pd.read_csv('NBA_Salary_1993.csv')

# %%
NBA_Salary_1994 = pd.read_csv('NBA_Salary_1994.csv')

# %%
NBA_Salary_1995 = pd.read_csv('NBA_Salary_1995.csv')

# %%
NBA_Salary_91to95 = pd.concat([NBA_Salary_1991,NBA_Salary_1992,NBA_Salary_1993,NBA_Salary_1994,NBA_Salary_1995])

# %%
NBA_Salary_91to95
# Out:
#     Team  Year            Player   Salary
# 0    BOS  1991     Robert Parish  2500000
# 1    BOS  1991        Larry Bird  1500000
# 2    BOS  1991      Kevin McHale  1400000
# 3    BOS  1991        Brian Shaw  1212000
# 4    BOS  1991        Joe Kleine   850000
# 5    BOS  1991       Ed Pinckney   750000
# 6    BOS  1991       John Bagley   550000
# 7    BOS  1991         Dee Brown   547000
# 8    BOS  1991     Michael Smith   525000
# 9    BOS  1991      Reggie Lewis   400000
# 10   BOS  1991      Kevin Gamble   375000
# 11   BOS  1991       Derek Smith   315000
# 12   BOS  1991  Stojko Vrankovic   222000
# 13   BOS  1991       Dave Popson    80000
# 14   BOS  1991       A.J. Wynder    30000
# 15   PHI  1991   Charles Barkley  2900000
# 16   PHI  1991    Johnny Dawkins  1500000
# 17   PHI  1991       Rick Mahorn  1330000
# 18   PHI  1991        Manute Bol  1300000
# 19   PHI  1991     Armen Gilliam  1200000
# 20   PHI  1991    Hersey Hawkins  1000000
# ...

# %%
NBA_Salary_96to17 = pd.read_csv('NBA_Salary_96to17.csv')

# %%
NBA_Salary_91to17 = pd.concat([NBA_Salary_91to95,NBA_Salary_96to17])

# %%
NBA_Salary_91to17.to_csv('NBA_Salary_91to17.csv',index=False)
